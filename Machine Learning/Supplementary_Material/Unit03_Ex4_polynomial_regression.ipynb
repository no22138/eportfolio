# %% [markdown]
# 18 cars passing a certain tollboth at different time of the day (x) with different speed (y)

# %%
import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

#NumPy has a method that lets us make a polynomial model
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

#specify how the line will display, we start at position 1, and end at position 22
myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# ### Our analysis

# %% [markdown]
# To identify the relationship between the variables and decide if the regression is linear or polynomial , we should first scatter plot the data

# %%
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.xlabel('Time of Day')
plt.ylabel('Speed of Cars')
plt.title('Scatter Plot of Time of Day vs Speed of Cars')
plt.show()

# %% [markdown]
# we can notice that the pattern is more polynomial because data don't follow a straight pattern ( it follows a curve )

# %%
import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

#NumPy has a method that lets us make a polynomial model
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

#specify how the line will display, we start at position 1, and end at position 22
myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# Parameters analysis :
# - mymodel = numpy.poly1d(numpy.polyfit(x, y, 3)) : the degree 3 refers to the degree of the polynomial equation
# - myline = numpy.linspace(1, 22, 100) : 100 values from 1 to 22

# %% [markdown]
# It is important to know how well the relationship between the values of the x- and y-axis is, if there are no relationship the polynomial regression can not be used to predict anything.
#
# The relationship is measured with a value called the r-squared.
#
# The r-squared value ranges from 0 to 1, where 0 means no relationship, and 1 means 100% related

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451026

# %% [markdown]
# ## Predict Future Values

# %% [markdown]
# Let us try to predict the speed of a car that passes the tollbooth at around 17 P.M

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269698007

# %% [markdown]
# ![img_polynomial_prediction.png](attachment:img_polynomial_prediction.png)

# %% [markdown]
# Let us try to predict the speed of a car that passes the tollbooth at around 4 P.M

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(4)
speed2 = mymodel(11)
speed3 = mymodel(20)
print("speed for 4 Pm ",speed)
print("speed for 11 Pm ",speed2)
print("speed for 20 Pm ",speed3)
# Out:
# speed for 4 Pm  71.16759559890431
# speed for 11 Pm  65.0327650041481
# speed for 20 Pm  97.76768832747531
