# %% [markdown]
# ## Importing the required packages

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Load the data

# %%
# Reading the data
df=pd.read_csv("FuelConsumption.csv")

# %%
# Take a look at the dataset
df.head(10)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
# 5       2014  ACURA         RLX     MID-SIZE         3.5          6
# 6       2014  ACURA          TL     MID-SIZE         3.5          6
# 7       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 8       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 9       2014  ACURA         TSX      COMPACT         2.4          4
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# ...

# %% [markdown]
# We tried to calculate the correlation directly on the 'df' dataframe, but we got an error since the dataframe contains categorical and numerical features. To calculate correlation, we should only consider numerical features.

# %%
# print the data type of the columns
print(df.dtypes)
# Out:
# MODELYEAR                     int64
# MAKE                         object
# MODEL                        object
# VEHICLECLASS                 object
# ENGINESIZE                  float64
# CYLINDERS                     int64
# TRANSMISSION                 object
# FUELTYPE                     object
# FUELCONSUMPTION_CITY        float64
# FUELCONSUMPTION_HWY         float64
# FUELCONSUMPTION_COMB        float64
# FUELCONSUMPTION_COMB_MPG      int64
# CO2EMISSIONS                  int64
# dtype: object

# %%
numeric_features = df.select_dtypes(include=[np.number])
numeric_features.columns
# Out:
# Index(['MODELYEAR', 'ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
numeric_features.corr()
# Out:
#                           MODELYEAR  ENGINESIZE  CYLINDERS  \
# MODELYEAR                       NaN         NaN        NaN
# ENGINESIZE                      NaN    1.000000   0.934011
# CYLINDERS                       NaN    0.934011   1.000000
# FUELCONSUMPTION_CITY            NaN    0.832225   0.796473
# FUELCONSUMPTION_HWY             NaN    0.778746   0.724594
# FUELCONSUMPTION_COMB            NaN    0.819482   0.776788
# FUELCONSUMPTION_COMB_MPG        NaN   -0.808554  -0.770430
# CO2EMISSIONS                    NaN    0.874154   0.849685
#
#                           FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# MODELYEAR                                  NaN                  NaN
# ENGINESIZE                            0.832225             0.778746
# CYLINDERS                             0.796473             0.724594
# FUELCONSUMPTION_CITY                  1.000000             0.965718
# FUELCONSUMPTION_HWY                   0.965718             1.000000
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# The pairplot function allows us to make plotting between all pairs of variables in the dataframe.

# %%
sns.pairplot(df, hue = "VEHICLECLASS")

# %% [markdown]
# The hue parameter allows us to assign different colors for distinct or unique values of a categorical feature.

# %%
plt.figure(figsize=(12, 6))
heatmap = sns.heatmap(numeric_features.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ## Plot to check the linearity

# %% [markdown]
# ## Data exploration

# %%
# Summarise the data
print(df.describe())
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
cdf=df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244
# 5         3.5          6                  10.0           230
# 6         3.5          6                  10.1           232
# 7         3.7          6                  11.1           255
# 8         3.7          6                  11.6           267

# %%
plt.scatter(cdf.FUELCONSUMPTION_COMB,cdf.CO2EMISSIONS, color='black')
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# As we have many lines with different directions, we can not say that we have a perfect linear relationship between the two variables FUELCONSUMPTION_COMB and Emission.

# %%
plt.scatter(cdf.ENGINESIZE,cdf.CO2EMISSIONS, color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# In this scatter plot we can according to the visualization say that we have a linear relationship between the two variables Engine size and Emission.

# %%
plt.scatter(cdf.CYLINDERS,cdf.CO2EMISSIONS, color='red')
plt.xlabel("Cylinders")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# In this scatter plot, we can clearly see that we don't have linear relationship between the Cylinders and Emission variables

# %% [markdown]
# Question : Which of the above variables do you think will work best to explain a linear relation with CO2 emission?
# Answer : I think that the variables that work best to explain linear relationship with CO2 emission is the second one, i.e., engine size.

# %% [markdown]
# ## Demo 2. Regression

# %% [markdown]
# ## Train-test data preparation

# %%
msk=np.random.rand(len(df))<0.8
train=cdf[msk]
test=cdf[~msk]

# %%
# Train data distribution
plt.scatter(train.ENGINESIZE,train.CO2EMISSIONS, color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# The distribution of the data considering the variables (Engine size, Emission) and the training split is the same as the one we visualized considering the whole cdf dataframe.

# %% [markdown]
# ## Using sklearn package for data modelling

# %%
from sklearn import linear_model
regr=linear_model.LinearRegression()

train_x=np.asanyarray(train[['ENGINESIZE']]) # Independant variable
train_y=np.asanyarray(train[['CO2EMISSIONS']]) # Dependant variable

regr.fit(train_x, train_y) # for training
# The coefficients
print('Coefficients:', regr.coef_) # slope
print('Intercept:', regr.intercept_) # intercept
# Out:
# Coefficients: [[38.95124494]]
# Intercept: [126.04679998]

# %%
# Plot outputs
plt.scatter(train.ENGINESIZE,train.CO2EMISSIONS,color='blue')
plt.plot(train_x,regr.coef_[0][0]*train_x + regr.intercept_[0],'-r')
plt.xlabel("Engine size")
plt.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')

# %% [markdown]
# ## Model evaluation

# %%
test_x=np.asanyarray(test[['ENGINESIZE']])
test_y=np.asanyarray(test[['CO2EMISSIONS']])

test_y_ = regr.predict(test_y) # for evaluation / testing

# %%
from sklearn.metrics import r2_score
print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_-test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_-test_y)**2))
print("R2-score: %.2f" % r2_score(test_y_,test_y))
# Out:
# Mean absolute error: 9599.37
# Residual sum of squares (MSE): 97525114.13
# R2-score: -16.22

# %% [markdown]
# According to the values of absolute error, MSE and R2 score , we can see that the model is not predicting well because the values are so high (Abs err and MSE). This is probably because the model was trained on insufficient samples and normally the model needs more data to learn and predict well during testing phase.

# %% [markdown]
# ## Nonlinear regression

# %% [markdown]
# #### Importing reqired dataset

# %%
df=pd.read_csv("china_gdp.csv")
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-dd5a04a965e6> in <module>()
# ----> 1 df=pd.read_csv("china_gdp.csv")
#       2 df.head(10)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %% [markdown]
# #### Plotting the dataset

# %%
plt.figure(figsize=(8,5))
x_data,y_data=(df["Year"].values,df["Value"].values)
plt.plot(x_data,y_data,'ro')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()
# Normalisation
xdata=x_data/max(x_data)
ydata=y_data/max(y_data)

plt.plot(xdata,ydata,'b')

# %% [markdown]
# Roughly looking look at the data visualisation, it appears that the logistic function could be a good representation for this very dataset. The logistic function has the property of starting with a slow growth, increasing growth in the middle, and then decreasing again at the end

# %% [markdown]
# #### Implement the logistic function

# %%
def sigmoid(x,Beta_1,Beta_2):
    y=1/(1+np.exp(-Beta_1*(x-Beta_2)))
    return y

# %% [markdown]
# #### Fit the logistic function on this dataset and estimate the relevant parameters

# %%
from scipy.optimize import curve_fit
popt,pcov=curve_fit(sigmoid,xdata,ydata)
print("beta_1=%f,beta_2=%f"%(popt[0],popt[1]))

##
x=np.linspace(1960,2015,55)
x=x/max(x)
plt.figure(figsize=(8,5))
y=sigmoid(x,*popt)
plt.plot(xdata,ydata,'ro',label='data')
plt.plot(x,y,linewidth=3.0,label='fit')
plt.legend(loc='best')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()
